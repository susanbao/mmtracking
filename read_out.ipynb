# %%
import pandas as pd

obj = pd.read_pickle(r'./out/mot17_ocsort.pkl')

# %%
obj['track_bboxes']
# Out:
# [[array([[0.00000000e+00, 1.39600000e+03, 3.68000000e+02, 1.54500000e+03,
#           7.22000000e+02, 9.98535156e-01],
#          [1.00000000e+00, 8.17000000e+02, 3.40250000e+02, 1.02400000e+03,
#           8.47500000e+02, 9.98535156e-01],
#          [2.00000000e+00, 1.82400000e+03, 4.13750000e+02, 1.92200000e+03,
#           6.37500000e+02, 9.98046875e-01],
#          [3.00000000e+00, 1.16500000e+03, 3.05750000e+02, 1.35900000e+03,
#           8.00500000e+02, 9.97558594e-01],
#          [4.00000000e+00, 1.54900000e+03, 4.16000000e+02, 1.63100000e+03,
#           7.09000000e+02, 9.97070312e-01],
#          [5.00000000e+00, 9.80500000e+02, 3.37000000e+02, 1.17300000e+03,
#           8.64000000e+02, 9.96582031e-01],
#          [6.00000000e+00, 1.31700000e+03, 4.28500000e+02, 1.40900000e+03,
#           7.16500000e+02, 9.92675781e-01],
#          [7.00000000e+00, 1.68800000e+03, 5.27500000e+02, 1.76400000e+03,
#           7.23500000e+02, 9.79003906e-01],
# ...
